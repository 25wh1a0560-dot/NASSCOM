# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0560-dot/NASSCOM/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

raw_sensor_data = []

for i in range(1, 101):
    # Timestamp in the format YYYY-MM-DD HH:MM:SS
    timestamp_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Unique device ID
    device_id = f"DEV{i:03d}"

    # Randomly choose device type
    device_type = random.choice(DEVICE_TYPES)

    # Randomly choose location
    location = random.choice(LOCATIONS)

    # Generate random value based on device type
    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    # Create a tuple
    reading = (timestamp_str, device_id, device_type, location, value)

    # Add tuple to the list
    raw_sensor_data.append(reading)

# Print all sensor readings
print("\nGenerated Sensor Readings:")
for reading in raw_sensor_data:
    print(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# Generated Sensor Readings:
# ('2026-07-19 13:19:29', 'DEV001', 'Humidity_Sensor', 'Warehouse', 35.98)
# ('2026-07-19 13:19:29', 'DEV002', 'Temperature_Sensor', 'Warehouse', 19.18)
# ('2026-07-19 13:19:29', 'DEV003', 'Humidity_Sensor', 'Lab2', 32.19)
# ('2026-07-19 13:19:29', 'DEV004', 'Humidity_Sensor', 'Lab2', 77.01)
# ('2026-07-19 13:19:29', 'DEV005', 'Temperature_Sensor', 'OfficeA', 27.1)
# ('2026-07-19 13:19:29', 'DEV006', 'Humidity_Sensor', 'OfficeA', 64.66)
# ('2026-07-19 13:19:29', 'DEV007', 'Light_Sensor', 'Lab2', 983.27)
# ('2026-07-19 13:19:29', 'DEV008', 'Light_Sensor', 'OfficeB', 112.77)
# ('2026-07-19 13:19:29', 'DEV009', 'Temperature_Sensor', 'Lab1', 29.62)
# ('2026-07-19 13:19:29', 'DEV072', 'Humidity_Sensor', 'Lab1', 50.63)
# ('2026-07-19 13:19:29', 'DEV073', 'Light_Sensor', 'OfficeB', 464.6)
# ('2026-07-19 13:19:29', 'DEV074', 'Humidity_Sensor', 'OfficeB', 35.43)
# ('2026-07-19 13:19:29', 'DEV075', 'Temperature_Sensor', 'Lab2', 22.52)
# ('2026-07-19 13:19:29', 'DEV076', 'Temperature_Sensor', 'Lab1', 24.95)
# ('2026-07-19 13:19:29', 'DEV077', 'Pressure_Sensor', 'OfficeB', 980.03)
# ('2026-07-19 13:19:29', 'DEV078', 'Pressure_Sensor', 'OfficeB', 1026.06)
# ('2026-07-19 13:19:29', 'DEV079', 'Light_Sensor', 'Lab2', 192.0)
# ('2026-07-19 13:19:29', 'DEV080', 'Temperature_Sensor', 'OfficeB', 22.35)
# ('2026-07-19 13:19:29', 'DEV081', 'Temperature_Sensor', 'Lab1', 29.05)
# ('2026-07-19 13:19:29', 'DEV082', 'Temperature_Sensor', 'Lab2', 28.49)
# ('2026-07-19 13:19:29', 'DEV083', 'Light_Sensor', 'Lab1', 171.36)
# ('2026-07-19 13:19:29', 'DEV084', 'Pressure_Sensor', 'OfficeA', 1014.92)
# ('2026-07-19 13:19:29', 'DEV085', 'Light_Sensor', 'Warehouse', 846.32)
# ('2026-07-19 13:19:29', 'DEV086', 'Light_Sensor', 'Lab2', 310.78)
# ('2026-07-19 13:19:29', 'DEV087', 'Pressure_Sensor', 'OfficeB', 999.96)
# ('2026-07-19 13:19:29', 'DEV088', 'Humidity_Sensor', 'OfficeA', 42.82)
# ('2026-07-19 13:19:29', 'DEV089', 'Humidity_Sensor', 'OfficeB', 78.97)
# ('2026-07-19 13:19:29', 'DEV090', 'Pressure_Sensor', 'Warehouse', 1021.05)
# ('2026-07-19 13:19:29', 'DEV091', 'Temperature_Sensor', 'Lab2', 18.9)
# ('2026-07-19 13:19:29', 'DEV092', 'Humidity_Sensor', 'OfficeA', 38.2)
# ('2026-07-19 13:19:29', 'DEV093', 'Light_Sensor', 'Warehouse', 939.94)
# ('2026-07-19 13:19:29', 'DEV094', 'Light_Sensor', 'Lab1', 637.75)
# ('2026-07-19 13:19:29', 'DEV095', 'Pressure_Sensor', 'Warehouse', 1004.28)
# ('2026-07-19 13:19:29', 'DEV096', 'Light_Sensor', 'OfficeB', 744.01)
# ('2026-07-19 13:19:29', 'DEV097', 'Pressure_Sensor', 'Lab2', 980.47)
# ('2026-07-19 13:19:29', 'DEV098', 'Temperature_Sensor', 'Lab1', 25.39)
# ('2026-07-19 13:19:29', 'DEV099', 'Temperature_Sensor', 'Lab2', 23.17)
# ('2026-07-19 13:19:29', 'DEV100', 'Temperature_Sensor', 'Lab1', 29.39)

# %%
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temp_dict = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp_dict)

# Print the temperature readings
print("\nTemperature Readings:")
for temp in temperature_readings:
    print(temp)
# Out:
# Temperature Readings:
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV002', 'location': 'Warehouse', 'temperature_celsius': 19.18}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV005', 'location': 'OfficeA', 'temperature_celsius': 27.1}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV009', 'location': 'Lab1', 'temperature_celsius': 29.62}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV019', 'location': 'OfficeB', 'temperature_celsius': 22.36}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV023', 'location': 'OfficeA', 'temperature_celsius': 18.83}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV035', 'location': 'Warehouse', 'temperature_celsius': 19.77}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV044', 'location': 'Lab2', 'temperature_celsius': 21.45}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV045', 'location': 'Lab2', 'temperature_celsius': 24.65}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV049', 'location': 'Lab2', 'temperature_celsius': 26.31}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV050', 'location': 'OfficeA', 'temperature_celsius': 24.15}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV054', 'location': 'Lab2', 'temperature_celsius': 18.62}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV058', 'location': 'Lab1', 'temperature_celsius': 20.82}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV075', 'location': 'Lab2', 'temperature_celsius': 22.52}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV076', 'location': 'Lab1', 'temperature_celsius': 24.95}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV080', 'location': 'OfficeB', 'temperature_celsius': 22.35}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV081', 'location': 'Lab1', 'temperature_celsius': 29.05}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV082', 'location': 'Lab2', 'temperature_celsius': 28.49}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV091', 'location': 'Lab2', 'temperature_celsius': 18.9}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV098', 'location': 'Lab1', 'temperature_celsius': 25.39}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV099', 'location': 'Lab2', 'temperature_celsius': 23.17}
# {'timestamp': '2026-07-19 13:19:29', 'device_id': 'DEV100', 'location': 'Lab1', 'temperature_celsius': 29.39}

# %%
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])   # Index 3 is the location

# Print the unique locations
print("\nUnique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'OfficeB', 'Lab2', 'Warehouse', 'Lab1', 'OfficeA'}

# %%
device_stats = {}

# Initialize the dictionary
for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

# Find the minimum and maximum values for each device type
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)

# Display the results
print("\nDevice Statistics:")
for device, stats in device_stats.items():
    print(device, ":", stats)
# Out:
# Device Statistics:
# Temperature_Sensor : (18.62, 29.62)
# Humidity_Sensor : (32.19, 79.37)
# Pressure_Sensor : (980.03, 1026.54)
# Light_Sensor : (112.77, 989.42)

# %%
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
sample_string = "PythonProgrammingIsFun"
# Extract elements from the 10th to the 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

# Print the results
print("\nReadings from 10th to 20th (inclusive):")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
# Readings from 10th to 20th (inclusive):
# ('2026-07-19 13:19:29', 'DEV010', 'Pressure_Sensor', 'OfficeB', 982.3)
# ('2026-07-19 13:19:29', 'DEV011', 'Pressure_Sensor', 'OfficeA', 1002.2)
# ('2026-07-19 13:19:29', 'DEV012', 'Pressure_Sensor', 'Lab1', 997.74)
# ('2026-07-19 13:19:29', 'DEV013', 'Humidity_Sensor', 'OfficeA', 39.87)
# ('2026-07-19 13:19:29', 'DEV014', 'Light_Sensor', 'OfficeA', 337.42)
# ('2026-07-19 13:19:29', 'DEV015', 'Humidity_Sensor', 'OfficeA', 64.62)
# ('2026-07-19 13:19:29', 'DEV016', 'Light_Sensor', 'Warehouse', 865.19)
# ('2026-07-19 13:19:29', 'DEV017', 'Humidity_Sensor', 'Lab2', 51.76)
# ('2026-07-19 13:19:29', 'DEV018', 'Light_Sensor', 'Lab1', 968.22)
# ('2026-07-19 13:19:29', 'DEV019', 'Temperature_Sensor', 'OfficeB', 22.36)
# ('2026-07-19 13:19:29', 'DEV020', 'Pressure_Sensor', 'Lab1', 1023.48)
#
# Every 5th reading:
# ('2026-07-19 13:19:29', 'DEV001', 'Humidity_Sensor', 'Warehouse', 35.98)
# ('2026-07-19 13:19:29', 'DEV006', 'Humidity_Sensor', 'OfficeA', 64.66)
# ('2026-07-19 13:19:29', 'DEV011', 'Pressure_Sensor', 'OfficeA', 1002.2)
# ('2026-07-19 13:19:29', 'DEV016', 'Light_Sensor', 'Warehouse', 865.19)
# ('2026-07-19 13:19:29', 'DEV021', 'Pressure_Sensor', 'OfficeA', 1004.59)
# ('2026-07-19 13:19:29', 'DEV026', 'Humidity_Sensor', 'Lab1', 45.5)
# ('2026-07-19 13:19:29', 'DEV031', 'Humidity_Sensor', 'Lab2', 46.27)
# ('2026-07-19 13:19:29', 'DEV036', 'Light_Sensor', 'Warehouse', 942.34)
# ('2026-07-19 13:19:29', 'DEV041', 'Pressure_Sensor', 'OfficeB', 994.75)
# ('2026-07-19 13:19:29', 'DEV046', 'Humidity_Sensor', 'Lab2', 66.15)
# ('2026-07-19 13:19:29', 'DEV051', 'Light_Sensor', 'Lab1', 322.82)
# ('2026-07-19 13:19:29', 'DEV056', 'Pressure_Sensor', 'OfficeA', 1009.1)
# ('2026-07-19 13:19:29', 'DEV061', 'Light_Sensor', 'Lab1', 675.46)
# ('2026-07-19 13:19:29', 'DEV066', 'Pressure_Sensor', 'OfficeB', 984.52)
# ('2026-07-19 13:19:29', 'DEV071', 'Light_Sensor', 'Lab2', 989.42)
# ('2026-07-19 13:19:29', 'DEV076', 'Temperature_Sensor', 'Lab1', 24.95)
# ('2026-07-19 13:19:29', 'DEV081', 'Temperature_Sensor', 'Lab1', 29.05)
# ('2026-07-19 13:19:29', 'DEV086', 'Light_Sensor', 'Lab2', 310.78)
# ('2026-07-19 13:19:29', 'DEV091', 'Temperature_Sensor', 'Lab2', 18.9)
# ('2026-07-19 13:19:29', 'DEV096', 'Light_Sensor', 'OfficeB', 744.01)

# %%
# Extract the substring "Programming"
substring_1 = sample_string[6:17]

# Extract the reverse of "Python" -> "nohtyP"
substring_2 = sample_string[5::-1]

# Print the results
print("\nSubstring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: Programming
# Substring 2: nohtyP

# %%
# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

# Print the results
print("\n5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Temperature_Sensor
# Device Type Suffix: Sensor

# %%
# 2.1 Function to get readings by location
print("\n--- Task 2: Function Definitions and Usage ---")

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


# Example usage
location = "Lab1"
lab1_readings = get_readings_by_location(raw_sensor_data, location)

print(f"\nSensor Readings for {location}:")
for reading in lab1_readings:
    print(reading)
# Out:
# --- Task 2: Function Definitions and Usage ---
#
# Sensor Readings for Lab1:
# ('2026-07-19 13:19:29', 'DEV009', 'Temperature_Sensor', 'Lab1', 29.62)
# ('2026-07-19 13:19:29', 'DEV012', 'Pressure_Sensor', 'Lab1', 997.74)
# ('2026-07-19 13:19:29', 'DEV018', 'Light_Sensor', 'Lab1', 968.22)
# ('2026-07-19 13:19:29', 'DEV020', 'Pressure_Sensor', 'Lab1', 1023.48)
# ('2026-07-19 13:19:29', 'DEV026', 'Humidity_Sensor', 'Lab1', 45.5)
# ('2026-07-19 13:19:29', 'DEV051', 'Light_Sensor', 'Lab1', 322.82)
# ('2026-07-19 13:19:29', 'DEV058', 'Temperature_Sensor', 'Lab1', 20.82)
# ('2026-07-19 13:19:29', 'DEV061', 'Light_Sensor', 'Lab1', 675.46)
# ('2026-07-19 13:19:29', 'DEV067', 'Pressure_Sensor', 'Lab1', 1012.87)
# ('2026-07-19 13:19:29', 'DEV072', 'Humidity_Sensor', 'Lab1', 50.63)
# ('2026-07-19 13:19:29', 'DEV076', 'Temperature_Sensor', 'Lab1', 24.95)
# ('2026-07-19 13:19:29', 'DEV081', 'Temperature_Sensor', 'Lab1', 29.05)
# ('2026-07-19 13:19:29', 'DEV083', 'Light_Sensor', 'Lab1', 171.36)
# ('2026-07-19 13:19:29', 'DEV094', 'Light_Sensor', 'Lab1', 637.75)
# ('2026-07-19 13:19:29', 'DEV098', 'Temperature_Sensor', 'Lab1', 25.39)
# ('2026-07-19 13:19:29', 'DEV100', 'Temperature_Sensor', 'Lab1', 29.39)

# %%
# 2.2 Function to calculate average temperature

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return round(average, 2)


# Example usage
avg_temperature = calculate_average_temperature(temperature_readings)

print("\nAverage Temperature:", avg_temperature)
# Out:
# Average Temperature: 23.67

# %%
# 2.3 Function to generate a formatted report line

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"


# Example usage
if len(temperature_readings) > 0:
    report = generate_report_line(temperature_readings[0])
    print("\nReport Line:")
    print(report)
# Out:
# Report Line:
# [2026-07-19 13:19:29] Device DEV002 at Warehouse: 19.18°C

# %%
# 3.1 Use the os module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.
print("\n--- Task 3: Core Library Usage ---")


reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' already exists.

# %%
# 3.2 Calculate the duration between the first and last timestamp

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string timestamps to datetime objects
    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    # Calculate duration
    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
# 3.3 Generate a list of 5 random integers between 100 and 200 (inclusive)

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)
# Out:
# Random Values:
# [120, 133, 111, 130, 197]
