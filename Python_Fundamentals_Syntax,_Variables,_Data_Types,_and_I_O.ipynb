# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0560-dot/NASSCOM/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello python')

if True:
  print("correct")
else:
  print("wont run")
# Out:
# hello python
# correct

# %%
name='alice'
age=12
height=5
print("name:",name)
print("age:",age)
print("height:",height)

name=123
print("new name=",name)
# Out:
# name: alice
# age: 12
# height: 5
# new name= 123

# %%
a=10
b=3.14
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
c='python'
d=True
e=[1,2,3,'four']
f={"name": "alice","age" :12}
print(type(c))
print(type(d))
print(type(e),e)
print(type(f))
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'>

# %%
print("Welcome to Python I/O!")
# Out:
# Welcome to Python I/O!

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)
# Out:
# Enter your name: deepika
# Hello, deepika

# %%
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your age: 19
# You will be 20 next year.
